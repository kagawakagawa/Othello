# %%
import math
import random
from game import State

# %%
from mcts100 import mcts100_action 
from mcts200 import mcts200_action 
from mcts500 import mcts500_action 
from mcts1000 import mcts1000_action 
from game import random_action

# %%
# プレイアウト 今の局面からゲーム終了まで戦うシミュレーションするやつ
def draw_playout(state):
    if state.is_draw():
         return 1
    if state.is_draw2():
         return 0.9
    if state.is_draw3():
         return 0.7
    if state.is_draw4():
         return 0.5
    if state.is_draw5():
         return 0.3
    if state.is_draw6():
         return 0
    

  # 次の状態の状態価値
    return draw_playout(state.next(random_action(state)))

def playout(state):
    if state.is_lose() :
        return -1
    if state.is_draw():
        return 0
        # 負けは -1、引き分けは 0
    return -playout(state.next(random_action(state)))

# %%
# モンテカルロ木探索で手を選ぶ
# 手の選び方、毎回選ぶときに引き分けを狙いに行く、ちょっとだけ勝ちも狙った方が引き分けしやすい？？
def draw_mcts_action(state):
    
  # モンテカルロ木探索
    class Node:
        
        # 初期化
        def __init__(self,state):
            self.state = state # 状態
            self.draw_w = 0 #提案累計価値#累計価値のみ変更、試行回数はそのままにしておこう
            self.w = 0 # 累計価値
            self.draw_n = 0
            self.n = 0 # 試行回数
            self.child_nodes = None # 子ノード群

        def evaluate(self):
            
            # ゲーム終了
            if self.state.is_done():
                if state.is_first_player():
                    
                    # 勝敗結果で価値を取得、引き分けに近いほど価値が高い、
                    # これにより作られる木が引き分けを狙う木になる、はず、、、

#                     if state.is_draw():
#                         value = 1
                    if state.is_draw2():
                        value = 0.9
                    if state.is_draw3():
                        value = 0.7
                    if state.is_draw4():
                        value = 0.5
                    if state.is_draw5():
                        value = 0.3
                    else:
                        value = 0
                    
                    self.draw_w += value
                    self.draw_n += 1
                # 後攻は普通に勝ったらポイントゲットとなる
                else:
                    # 勝敗結果で価値を取得
                    value = -1 if self.state.is_lose() else 0 # 負けは -1、引き分けは 0

            # 累計価値を試行回数の更新
                    self.w += value
                    self.n += 1
                return value
          #子ノードが存在しないとき
            if not self.child_nodes:
                if state.is_first_player():
                    value = draw_playout(self.state)
                    self.draw_w += value
                    self.draw_n += 1
                else:
                    value = playout(self.state)

            # 累計価値と試行回数の更新
                    self.w += value
                    self.n += 1

                # 子ノードの展開
                if self.n == 10:

                    self.expand()
                return value

          # 子ノードが存在するとき
            else:
                # UCB1が最大の子ノードの評価で価値を取得
                if state.is_first_player():  
                    value = self.next_child_node().evaluate()
                    self.draw_w += value
                    self.draw_n += 1
                else:
                    value = -self.next_child_node().evaluate()
                    self.w += value
                    self.n += 1
                return value
            
        # 子ノードの展開
        def expand(self):
            legal_actions = self.state.legal_actions()
            self.child_nodes = []
            for action in legal_actions:
                self.child_nodes.append(Node(self.state.next(action)))

        # UCB1が最大の子ノードの取得
        # ここでの最大値を持つノードが次の手に選ばれる、今回はそうではなく引き分けを狙えそうな
        # 物を選ぶためargmaxにはならない
        # どうにかしてここが平均くらいの手を選ぶようにして展開するノードが引き分けを狙えるノードにしたい
        
        def next_child_node(self):
            for child_node in self.child_nodes:
                if child_node.n == 0:
                    return child_node

          # UCB1の計算
            t = 0
            for c in self.child_nodes:
                t += c.n
            ucb1_values = []
            for child_node in self.child_nodes:
                
                if state.is_first_player():
                    ucb1_values.append(child_node.draw_w/child_node.n+(2*math.log(t)/child_node.n)**0.5)
                else:
                    ucb1_values.append(-child_node.w/child_node.n+(2*math.log(t)/child_node.n)**0.5)

          # UCB1が最大の子ノードを返す
            return self.child_nodes[argmax(ucb1_values)] 
        
          # そうではなく最も0に近いノードを選べばいいのではないだろうか
            #return self.child_nodes[select0(ucb1_values)]


        # 現在の局面のノードの作成
    root_node = Node(state)
    root_node.expand()

      # n回のシミュレーションを実行　この数によって強さが変動する
    for _ in range(1000):
        root_node.evaluate()

      # 試行回数の最大値を持つ行動を返す
    legal_actions = state.legal_actions()
    n_list = []
    for c in root_node.child_nodes:
        n_list.append(c.n)
    return legal_actions[argmax(n_list)]
#########うまくいかなかったら返り値とかの符号を全部変えよう

# %%
#ランダムに手を打つやつ
def random_action(state):
    legal_actions = state.legal_actions()
    return legal_actions[random.randint(0,len(legal_actions)-1)]

# 最大値のインデックスを返す
def argmax(collection,key=None):
    return collection.index(max(collection))


import matplotlib.pyplot as plt
import random 
import numpy as np


# tatakaimasu


# パラメータ
EP_GAME_COUNT = 1000  # 1評価当たりのゲーム数

# 先手プレイヤーのポイント
def first_player_point(ended_state):
  # 1:先手勝利、0:先手敗北または引分け
    if ended_state.is_lose():
        return 0 if ended_state.is_first_player() else 1
    return 0

# 1ゲームの実行
def play(next_actions):
  # 状態の生成
    state = State()

  # ゲーム終了までループ
    while True:
    # ゲーム終了時
        if state.is_done():
            break

    # 行動の取得
        next_action = next_actions[0] if state.is_first_player() else next_actions[1]
        action = next_action(state)

    # 次の状態の取得
        state = state.next(action)

  # 先手プレイヤーのポイントを返す
    return first_player_point(state)#数字はそのまま勝った回数となっている

# 任意のアルゴリズムの評価
def evaluate_algorithm_of(label,next_actions):
  # 複数回の対戦を繰り返す
    total_point = 0
    wp_list = []
    for i in range(EP_GAME_COUNT):
    # 1ゲームの実行
    # 先攻後攻毎回プログラムを切り替える
    # 
        if i%2 == 0:
            total_point += play(next_actions)
            # 現時点での勝率の計算
            now_average_point = total_point/(i+1)
            # 配列には毎回現時点での勝率を追加する
            wp_list.append(now_average_point*100)
            # 先攻が負けた場合相手が勝ったということで１－１で０点が加算される
        else:
            total_point += 1-play(list(reversed(next_actions)))
            now_average_point = total_point/(i+1)
            wp_list.append(now_average_point*100)
# reversed はリストを逆にするやつ、先攻後攻入れ替えたってこと
    
    # 出力、グラフの表示
    # 最後まで毎回計算し最後にグラフの出力
        print('\nEvaluate {}/{}'.format(i+1,EP_GAME_COUNT),end='')
#         print(self.pieces.count(1),end="")
#         print("対",end="")
#         print(self.enemy_pieces.count(1))
    print('')

  # 平均ポイントの計算
    average_point = total_point/EP_GAME_COUNT
    print(label.format(average_point))
    x = list(range(1,1+EP_GAME_COUNT))
    y = wp_list
    plt.title('result')
    plt.ylabel('winning parcentage')
    plt.xlabel('times')
    plt.plot(x,y,color = "red",marker = "",label = "changes")
    plt.legend()
    plt.show

# %%
#VSランダム
#更新の仕方
next_actions = (draw_mcts_newaction,random_action)
#next_actions = (random_action,random_action)
evaluate_algorithm_of('VS_Program {:.3f}',next_actions)
# Out:
# Evaluate 1/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 5>()
#       3 next_actions = (draw_mcts_newaction,random_action)
#       4 #next_actions = (random_action,random_action)
# ----> 5 evaluate_algorithm_of('VS_Program {:.3f}',next_actions)
#
# Input In [8], in evaluate_algorithm_of(label, next_actions)
#      64     wp_list.append(now_average_point*100)
#      65     # 先攻が負けた場合相手が勝ったということで１－１で０点が加算される
#      66 else:
# ---> 67     total_point += 1-play(list(reversed(next_actions)))
#      68     now_average_point = total_point/(i+1)
#      69     wp_list.append(now_average_point*100)
#
# Input In [8], in play(next_actions)
#      40 # 行動の取得
#      41     next_action = next_actions[0] if state.is_first_player() else next_actions[1]
# ---> 42     action = next_action(state)
#      44 # 次の状態の取得
#      45     state = state.next(action)
#
# Input In [4], in draw_mcts_newaction(state)
#     122   # n回のシミュレーションを実行　この数によって強さが変動する
#     123 for _ in range(1000):
# --> 124     root_node.evaluate()
#     126   # 試行回数の最大値を持つ行動を返す
#     127 legal_actions = state.legal_actions()
#
# Input In [4], in draw_mcts_newaction.<locals>.Node.evaluate(self)
#      75     self.draw_n += 1
#      76 else:
# ---> 77     value = -self.next_child_node().evaluate()
#      78     self.w += value
#      79     self.n += 1
#
# Input In [4], in draw_mcts_newaction.<locals>.Node.evaluate(self)
#      75     self.draw_n += 1
#      76 else:
# ---> 77     value = -self.next_child_node().evaluate()
#      78     self.w += value
#      79     self.n += 1
#
# Input In [4], in draw_mcts_newaction.<locals>.Node.evaluate(self)
#      75     self.draw_n += 1
#      76 else:
# ---> 77     value = -self.next_child_node().evaluate()
#      78     self.w += value
#      79     self.n += 1
#
# Input In [4], in draw_mcts_newaction.<locals>.Node.evaluate(self)
#      55         self.draw_n += 1
#      56     else:
# ---> 57         value = playout(self.state)
#      59 # 累計価値と試行回数の更新
#      60         self.w += value
#
# Input In [3], in playout(state)
#      24     return 0
#      25     # 負けは -1、引き分けは 0
# ---> 26 return -playout(state.next(random_action(state)))
#
# Input In [3], in playout(state)
#      24     return 0
#      25     # 負けは -1、引き分けは 0
# ---> 26 return -playout(state.next(random_action(state)))
#
#     [... skipping similar frames: playout at line 26 (14 times)]
#
# Input In [3], in playout(state)
#      24     return 0
#      25     # 負けは -1、引き分けは 0
# ---> 26 return -playout(state.next(random_action(state)))
#
# Input In [8], in random_action(state)
#       2 def random_action(state):
# ----> 3     legal_actions = state.legal_actions()
#       4     return legal_actions[random.randint(0,len(legal_actions)-1)]
#
# File ~/オセロ/game.py:121, in State.legal_actions(self)
#     119 for j in range(0,8):
#     120     for i in range(0,8):
# --> 121         if self.is_legal_action_xy(i,j):
#     122             actions.append(i+j*8)
#     123 if len(actions) == 0:
#
# File ~/オセロ/game.py:191, in State.is_legal_action_xy(self, x, y, flip)
#     189 flag = False
#     190 for dx,dy in self.dxy:
# --> 191     if is_legal_action_xy_dxy(x,y,dx,dy):
#     192         flag = True
#     193 return flag
#
# File ~/オセロ/game.py:134, in State.is_legal_action_xy.<locals>.is_legal_action_xy_dxy(x, y, dx, dy)
#     132 def is_legal_action_xy_dxy(x,y,dx,dy):
#     133     #一つ目　相手の石
# --> 134     x,y = x+dx,y+dy
#     136     if y<0 or 7<y or x<0 or 7<x or self.enemy_pieces[x+y*8]!=1:#x+y*8は自分の座標
#     137         return False
#
# KeyboardInterrupt:

# %%
next_actions = (draw_mcts_newaction,mcts1000_action)
#next_actions = (random_action,random_action)
evaluate_algorithm_of('VS_Program {:.3f}',next_actions)
# Out:
# Evaluate 1/1000
# Evaluate 2/1000
# Evaluate 3/1000
# Evaluate 4/1000
# Evaluate 5/1000
# Evaluate 6/1000
# Evaluate 7/1000
# Evaluate 8/1000
# Evaluate 9/1000
# Evaluate 10/1000
# Evaluate 11/1000
# Evaluate 12/1000
# Evaluate 13/1000
# Evaluate 14/1000
# Evaluate 15/1000
# Evaluate 16/1000
# Evaluate 17/1000
# Evaluate 18/1000
# Evaluate 19/1000
# Evaluate 20/1000
# Evaluate 21/1000
# Evaluate 22/1000
# Evaluate 23/1000
# Evaluate 24/1000
# Evaluate 25/1000
# Evaluate 26/1000
# Evaluate 27/1000
# Evaluate 28/1000
# Evaluate 29/1000
# Evaluate 30/1000
# Evaluate 31/1000
# Evaluate 32/1000
# Evaluate 33/1000
# Evaluate 34/1000
# Evaluate 35/1000
# Evaluate 36/1000
# Evaluate 37/1000
# Evaluate 38/1000
# Evaluate 39/1000
# Evaluate 40/1000
# Evaluate 41/1000
# Evaluate 42/1000
# Evaluate 43/1000
# Evaluate 44/1000
# Evaluate 45/1000
# Evaluate 46/1000
# Evaluate 47/1000
# Evaluate 48/1000
# Evaluate 49/1000
# Evaluate 50/1000
# Evaluate 51/1000
# Evaluate 52/1000
# Evaluate 53/1000
# Evaluate 54/1000
# Evaluate 55/1000
# Evaluate 56/1000
# Evaluate 57/1000
# Evaluate 58/1000
# Evaluate 59/1000
# Evaluate 60/1000
# Evaluate 61/1000
# Evaluate 62/1000
# Evaluate 63/1000
# Evaluate 64/1000
# Evaluate 65/1000
# Evaluate 66/1000
# Evaluate 67/1000
# Evaluate 68/1000
# Evaluate 69/1000
# Evaluate 70/1000
# Evaluate 71/1000
# Evaluate 72/1000
# Evaluate 73/1000
# Evaluate 74/1000
# Evaluate 75/1000
# Evaluate 76/1000
# Evaluate 77/1000
# Evaluate 78/1000
# Evaluate 79/1000
# Evaluate 80/1000
# Evaluate 81/1000
# Evaluate 82/1000
# Evaluate 83/1000
# Evaluate 84/1000
# Evaluate 85/1000
# Evaluate 86/1000
# Evaluate 87/1000
# Evaluate 88/1000
# Evaluate 89/1000
# Evaluate 90/1000
# Evaluate 91/1000
# Evaluate 92/1000
# Evaluate 93/1000
# Evaluate 94/1000
# Evaluate 95/1000
# Evaluate 96/1000
# Evaluate 97/1000
# Evaluate 98/1000
# Evaluate 99/1000
# Evaluate 100/1000
# Evaluate 101/1000
# Evaluate 102/1000
# Evaluate 103/1000
# Evaluate 104/1000
# Evaluate 105/1000
# Evaluate 106/1000
# Evaluate 107/1000
# Evaluate 108/1000
# Evaluate 109/1000
# Evaluate 110/1000
# Evaluate 111/1000
# Evaluate 112/1000
# Evaluate 113/1000
# Evaluate 114/1000
# Evaluate 115/1000
# Evaluate 116/1000
# Evaluate 117/1000
# Evaluate 118/1000
# Evaluate 119/1000
# Evaluate 120/1000
# Evaluate 121/1000
# Evaluate 122/1000
# Evaluate 123/1000
# Evaluate 124/1000
# Evaluate 125/1000
# Evaluate 126/1000
# Evaluate 127/1000
# Evaluate 128/1000
# Evaluate 129/1000
# Evaluate 130/1000
# Evaluate 131/1000
# Evaluate 132/1000
# Evaluate 133/1000
# Evaluate 134/1000
# Evaluate 135/1000
# Evaluate 136/1000
# Evaluate 137/1000
# Evaluate 138/1000
# Evaluate 139/1000
# Evaluate 140/1000
# Evaluate 141/1000
# Evaluate 142/1000
# Evaluate 143/1000
# Evaluate 144/1000
# Evaluate 145/1000
# Evaluate 146/1000
# Evaluate 147/1000
# Evaluate 148/1000
# Evaluate 149/1000
# Evaluate 150/1000
# Evaluate 151/1000
# Evaluate 152/1000
# Evaluate 153/1000
# Evaluate 154/1000
# Evaluate 155/1000
# Evaluate 156/1000
# Evaluate 157/1000
# Evaluate 158/1000
# Evaluate 159/1000
# Evaluate 160/1000
# Evaluate 161/1000
# Evaluate 162/1000
# Evaluate 163/1000
# Evaluate 164/1000
# Evaluate 165/1000
# Evaluate 166/1000
# Evaluate 167/1000
# Evaluate 168/1000
# Evaluate 169/1000
# Evaluate 170/1000
# Evaluate 171/1000
# Evaluate 172/1000
# Evaluate 173/1000
# Evaluate 174/1000
# Evaluate 175/1000
# Evaluate 176/1000
# Evaluate 177/1000
# Evaluate 178/1000
# Evaluate 179/1000
# Evaluate 180/1000
# Evaluate 181/1000
# Evaluate 182/1000
# Evaluate 183/1000
# Evaluate 184/1000
# Evaluate 185/1000
# Evaluate 186/1000
# Evaluate 187/1000
# Evaluate 188/1000
# Evaluate 189/1000
# Evaluate 190/1000
# Evaluate 191/1000
# Evaluate 192/1000
# Evaluate 193/1000
# Evaluate 194/1000
# Evaluate 195/1000
# Evaluate 196/1000
# Evaluate 197/1000
# Evaluate 198/1000
# Evaluate 199/1000
# Evaluate 200/1000
# Evaluate 201/1000
# Evaluate 202/1000
# Evaluate 203/1000
# Evaluate 204/1000
# Evaluate 205/1000
# Evaluate 206/1000
# Evaluate 207/1000
# Evaluate 208/1000
# Evaluate 209/1000
# Evaluate 210/1000
# Evaluate 211/1000
# Evaluate 212/1000
# Evaluate 213/1000
# Evaluate 214/1000
# Evaluate 215/1000
# Evaluate 216/1000
# Evaluate 217/1000
# Evaluate 218/1000
# Evaluate 219/1000
# Evaluate 220/1000
# Evaluate 221/1000
# Evaluate 222/1000
# Evaluate 223/1000
# Evaluate 224/1000
# Evaluate 225/1000
# Evaluate 226/1000
# Evaluate 227/1000
# Evaluate 228/1000
# Evaluate 229/1000
# Evaluate 230/1000
# Evaluate 231/1000
# Evaluate 232/1000
# Evaluate 233/1000
# Evaluate 234/1000
# Evaluate 235/1000
# Evaluate 236/1000
# Evaluate 237/1000
# Evaluate 238/1000
# Evaluate 239/1000
# Evaluate 240/1000
# Evaluate 241/1000
# Evaluate 242/1000
# Evaluate 243/1000
# Evaluate 244/1000
# Evaluate 245/1000
# Evaluate 246/1000
# Evaluate 247/1000
# Evaluate 248/1000
# Evaluate 249/1000
# Evaluate 250/1000
# Evaluate 251/1000
# Evaluate 252/1000
# Evaluate 253/1000
# Evaluate 254/1000
# Evaluate 255/1000
# Evaluate 256/1000
# Evaluate 257/1000
# Evaluate 258/1000
# Evaluate 259/1000
# Evaluate 260/1000
# Evaluate 261/1000
# Evaluate 262/1000
# Evaluate 263/1000
# Evaluate 264/1000
# Evaluate 265/1000
# Evaluate 266/1000
# Evaluate 267/1000
# Evaluate 268/1000
# Evaluate 269/1000
# Evaluate 270/1000
# Evaluate 271/1000
# Evaluate 272/1000
# Evaluate 273/1000
# Evaluate 274/1000
# Evaluate 275/1000
# Evaluate 276/1000
# Evaluate 277/1000
# Evaluate 278/1000
# Evaluate 279/1000
# Evaluate 280/1000
# Evaluate 281/1000
# Evaluate 282/1000
# Evaluate 283/1000
# Evaluate 284/1000
# Evaluate 285/1000
# Evaluate 286/1000
# Evaluate 287/1000
# Evaluate 288/1000
# Evaluate 289/1000
# Evaluate 290/1000
# Evaluate 291/1000
# Evaluate 292/1000
# Evaluate 293/1000
# Evaluate 294/1000
# Evaluate 295/1000
# Evaluate 296/1000
# Evaluate 297/1000
# Evaluate 298/1000
# Evaluate 299/1000
# Evaluate 300/1000
# Evaluate 301/1000
# Evaluate 302/1000
# Evaluate 303/1000
# Evaluate 304/1000
# Evaluate 305/1000
# Evaluate 306/1000
# Evaluate 307/1000
# Evaluate 308/1000
# Evaluate 309/1000
# Evaluate 310/1000
# Evaluate 311/1000
# Evaluate 312/1000
# Evaluate 313/1000
# Evaluate 314/1000
# Evaluate 315/1000
# Evaluate 316/1000
# Evaluate 317/1000
# Evaluate 318/1000
# Evaluate 319/1000
# Evaluate 320/1000
# Evaluate 321/1000
# Evaluate 322/1000
# Evaluate 323/1000
# Evaluate 324/1000
# Evaluate 325/1000
# Evaluate 326/1000
# Evaluate 327/1000
# Evaluate 328/1000
# Evaluate 329/1000
# Evaluate 330/1000
# Evaluate 331/1000
# Evaluate 332/1000
# Evaluate 333/1000
# Evaluate 334/1000
# Evaluate 335/1000
# Evaluate 336/1000
# Evaluate 337/1000
# Evaluate 338/1000
# Evaluate 339/1000
# Evaluate 340/1000
# Evaluate 341/1000
# Evaluate 342/1000
# Evaluate 343/1000
# Evaluate 344/1000
# Evaluate 345/1000
# Evaluate 346/1000
# Evaluate 347/1000
# Evaluate 348/1000
# Evaluate 349/1000
# Evaluate 350/1000
# Evaluate 351/1000
# Evaluate 352/1000
# Evaluate 353/1000
# Evaluate 354/1000
# Evaluate 355/1000
# Evaluate 356/1000
# Evaluate 357/1000
# Evaluate 358/1000
# Evaluate 359/1000
# Evaluate 360/1000
# Evaluate 361/1000
# Evaluate 362/1000
# Evaluate 363/1000
# Evaluate 364/1000
# Evaluate 365/1000
# Evaluate 366/1000
# Evaluate 367/1000
# Evaluate 368/1000
# Evaluate 369/1000
# Evaluate 370/1000
# Evaluate 371/1000
# Evaluate 372/1000
# Evaluate 373/1000
# Evaluate 374/1000
# Evaluate 375/1000
# Evaluate 376/1000
# Evaluate 377/1000
# Evaluate 378/1000
# Evaluate 379/1000
# Evaluate 380/1000
# Evaluate 381/1000
# Evaluate 382/1000
# Evaluate 383/1000
# Evaluate 384/1000
# Evaluate 385/1000
# Evaluate 386/1000
# Evaluate 387/1000
# Evaluate 388/1000
# Evaluate 389/1000
# Evaluate 390/1000
# Evaluate 391/1000
# Evaluate 392/1000
# Evaluate 393/1000
# Evaluate 394/1000
# Evaluate 395/1000
# Evaluate 396/1000
# Evaluate 397/1000
# Evaluate 398/1000
# Evaluate 399/1000
# Evaluate 400/1000
# Evaluate 401/1000
# Evaluate 402/1000
# Evaluate 403/1000
# Evaluate 404/1000
# Evaluate 405/1000
# Evaluate 406/1000
# Evaluate 407/1000
# Evaluate 408/1000
# Evaluate 409/1000
# Evaluate 410/1000
# Evaluate 411/1000
# Evaluate 412/1000
# Evaluate 413/1000
# Evaluate 414/1000
# Evaluate 415/1000
# Evaluate 416/1000
# Evaluate 417/1000
# Evaluate 418/1000
# Evaluate 419/1000
# Evaluate 420/1000
# Evaluate 421/1000
# Evaluate 422/1000
# Evaluate 423/1000
# Evaluate 424/1000
# Evaluate 425/1000
# Evaluate 426/1000
# Evaluate 427/1000
# Evaluate 428/1000
# Evaluate 429/1000
# Evaluate 430/1000
# Evaluate 431/1000
# Evaluate 432/1000
# Evaluate 433/1000
# Evaluate 434/1000
# Evaluate 435/1000
# Evaluate 436/1000
# Evaluate 437/1000
# Evaluate 438/1000
# Evaluate 439/1000
# Evaluate 440/1000
# Evaluate 441/1000
# Evaluate 442/1000
# Evaluate 443/1000
# Evaluate 444/1000
# Evaluate 445/1000
# Evaluate 446/1000
# Evaluate 447/1000
# Evaluate 448/1000
# Evaluate 449/1000
# Evaluate 450/1000
# Evaluate 451/1000
# Evaluate 452/1000
# Evaluate 453/1000
# Evaluate 454/1000
# Evaluate 455/1000
# Evaluate 456/1000
# Evaluate 457/1000
# Evaluate 458/1000
# Evaluate 459/1000
# Evaluate 460/1000
# Evaluate 461/1000
# Evaluate 462/1000
# Evaluate 463/1000
# Evaluate 464/1000
# Evaluate 465/1000
# Evaluate 466/1000
# Evaluate 467/1000
# Evaluate 468/1000
# Evaluate 469/1000
# Evaluate 470/1000
# Evaluate 471/1000
# Evaluate 472/1000
# Evaluate 473/1000
# Evaluate 474/1000
# Evaluate 475/1000
# Evaluate 476/1000
# Evaluate 477/1000
# Evaluate 478/1000
# Evaluate 479/1000
# Evaluate 480/1000
# Evaluate 481/1000
# Evaluate 482/1000
# Evaluate 483/1000
# Evaluate 484/1000
# Evaluate 485/1000
# Evaluate 486/1000
# Evaluate 487/1000
# Evaluate 488/1000
# Evaluate 489/1000
# Evaluate 490/1000
# Evaluate 491/1000
# Evaluate 492/1000
# Evaluate 493/1000
# Evaluate 494/1000
# Evaluate 495/1000
# Evaluate 496/1000
# Evaluate 497/1000
# Evaluate 498/1000
# Evaluate 499/1000
# Evaluate 500/1000
# Evaluate 501/1000
# Evaluate 502/1000
# Evaluate 503/1000
# Evaluate 504/1000
# Evaluate 505/1000
# Evaluate 506/1000
# Evaluate 507/1000
# Evaluate 508/1000
# Evaluate 509/1000
# Evaluate 510/1000
# Evaluate 511/1000
# Evaluate 512/1000
# Evaluate 513/1000
# Evaluate 514/1000
# Evaluate 515/1000
# Evaluate 516/1000
# Evaluate 517/1000
# Evaluate 518/1000
# Evaluate 519/1000
# Evaluate 520/1000
# Evaluate 521/1000
# Evaluate 522/1000
# Evaluate 523/1000
# Evaluate 524/1000
# Evaluate 525/1000
# Evaluate 526/1000
# Evaluate 527/1000
# Evaluate 528/1000
# Evaluate 529/1000
# Evaluate 530/1000
# Evaluate 531/1000
# Evaluate 532/1000
# Evaluate 533/1000
# Evaluate 534/1000
# Evaluate 535/1000
# Evaluate 536/1000
# Evaluate 537/1000
# Evaluate 538/1000
# Evaluate 539/1000
# Evaluate 540/1000
# Evaluate 541/1000
# Evaluate 542/1000
# Evaluate 543/1000
# Evaluate 544/1000
# Evaluate 545/1000
# Evaluate 546/1000
# Evaluate 547/1000
# Evaluate 548/1000
# Evaluate 549/1000
# Evaluate 550/1000
# Evaluate 551/1000
# Evaluate 552/1000
# Evaluate 553/1000
# Evaluate 554/1000
# Evaluate 555/1000
# Evaluate 556/1000
# Evaluate 557/1000
# Evaluate 558/1000
# Evaluate 559/1000
# Evaluate 560/1000
# Evaluate 561/1000
# Evaluate 562/1000
# Evaluate 563/1000
# Evaluate 564/1000
# Evaluate 565/1000
# Evaluate 566/1000
# Evaluate 567/1000
# Evaluate 568/1000
# Evaluate 569/1000
# Evaluate 570/1000
# Evaluate 571/1000
# Evaluate 572/1000
# Evaluate 573/1000
# Evaluate 574/1000
# Evaluate 575/1000
# Evaluate 576/1000
# Evaluate 577/1000
# Evaluate 578/1000
# Evaluate 579/1000
# Evaluate 580/1000
# Evaluate 581/1000
# Evaluate 582/1000
# Evaluate 583/1000
# Evaluate 584/1000
# Evaluate 585/1000
# Evaluate 586/1000
# Evaluate 587/1000
# Evaluate 588/1000
# Evaluate 589/1000
# Evaluate 590/1000
# Evaluate 591/1000
# Evaluate 592/1000
# Evaluate 593/1000
# Evaluate 594/1000
# Evaluate 595/1000
# Evaluate 596/1000
# Evaluate 597/1000
# Evaluate 598/1000
# Evaluate 599/1000
# Evaluate 600/1000
# Evaluate 601/1000
# Evaluate 602/1000
# Evaluate 603/1000
# Evaluate 604/1000
# Evaluate 605/1000
# Evaluate 606/1000
# Evaluate 607/1000
# Evaluate 608/1000
# Evaluate 609/1000
# Evaluate 610/1000
# Evaluate 611/1000
# Evaluate 612/1000
# Evaluate 613/1000
# Evaluate 614/1000
# Evaluate 615/1000
# Evaluate 616/1000
# Evaluate 617/1000
# Evaluate 618/1000
# Evaluate 619/1000
# Evaluate 620/1000
# Evaluate 621/1000
# Evaluate 622/1000
# Evaluate 623/1000
# Evaluate 624/1000
# Evaluate 625/1000
# Evaluate 626/1000
# Evaluate 627/1000
# Evaluate 628/1000
# Evaluate 629/1000
# Evaluate 630/1000
# Evaluate 631/1000
# Evaluate 632/1000
# Evaluate 633/1000
# Evaluate 634/1000
# Evaluate 635/1000
# Evaluate 636/1000
# Evaluate 637/1000
# Evaluate 638/1000
# Evaluate 639/1000
# Evaluate 640/1000
# Evaluate 641/1000
# Evaluate 642/1000
# Evaluate 643/1000
# Evaluate 644/1000
# Evaluate 645/1000
# Evaluate 646/1000
# Evaluate 647/1000
# Evaluate 648/1000
# Evaluate 649/1000
# Evaluate 650/1000
# Evaluate 651/1000
# Evaluate 652/1000
# Evaluate 653/1000
# Evaluate 654/1000
# Evaluate 655/1000
# Evaluate 656/1000
# Evaluate 657/1000
# Evaluate 658/1000
# Evaluate 659/1000
# Evaluate 660/1000
# Evaluate 661/1000
# Evaluate 662/1000
# Evaluate 663/1000
# Evaluate 664/1000
# Evaluate 665/1000
# Evaluate 666/1000
# Evaluate 667/1000
# Evaluate 668/1000
# Evaluate 669/1000
# Evaluate 670/1000
# Evaluate 671/1000
# Evaluate 672/1000
# Evaluate 673/1000
# Evaluate 674/1000
# Evaluate 675/1000
# Evaluate 676/1000
# Evaluate 677/1000
# Evaluate 678/1000
# Evaluate 679/1000
# Evaluate 680/1000
# Evaluate 681/1000
# Evaluate 682/1000
# Evaluate 683/1000
# Evaluate 684/1000
# Evaluate 685/1000
# Evaluate 686/1000
# Evaluate 687/1000
# Evaluate 688/1000
# Evaluate 689/1000
# Evaluate 690/1000
# Evaluate 691/1000
# Evaluate 692/1000
# Evaluate 693/1000
# Evaluate 694/1000
# Evaluate 695/1000
# Evaluate 696/1000
# Evaluate 697/1000
# Evaluate 698/1000
# Evaluate 699/1000
# Evaluate 700/1000
# Evaluate 701/1000
# Evaluate 702/1000
# Evaluate 703/1000
# Evaluate 704/1000
# Evaluate 705/1000
# Evaluate 706/1000
# Evaluate 707/1000
# Evaluate 708/1000
# Evaluate 709/1000
# Evaluate 710/1000
# Evaluate 711/1000
# Evaluate 712/1000
# Evaluate 713/1000
# Evaluate 714/1000
# Evaluate 715/1000
# Evaluate 716/1000
# Evaluate 717/1000
# Evaluate 718/1000
# Evaluate 719/1000
# Evaluate 720/1000
# Evaluate 721/1000
# Evaluate 722/1000
# Evaluate 723/1000
# Evaluate 724/1000
# Evaluate 725/1000
# Evaluate 726/1000
# Evaluate 727/1000
# Evaluate 728/1000
# Evaluate 729/1000
# Evaluate 730/1000
# Evaluate 731/1000
# Evaluate 732/1000
# Evaluate 733/1000
# Evaluate 734/1000
# Evaluate 735/1000
# Evaluate 736/1000
# Evaluate 737/1000
# Evaluate 738/1000
# Evaluate 739/1000
# Evaluate 740/1000
# Evaluate 741/1000
# Evaluate 742/1000
# Evaluate 743/1000
# Evaluate 744/1000
# Evaluate 745/1000
# Evaluate 746/1000
# Evaluate 747/1000
# Evaluate 748/1000
# Evaluate 749/1000
# Evaluate 750/1000
# Evaluate 751/1000
# Evaluate 752/1000
# Evaluate 753/1000
# Evaluate 754/1000
# Evaluate 755/1000
# Evaluate 756/1000
# Evaluate 757/1000
# Evaluate 758/1000
# Evaluate 759/1000
# Evaluate 760/1000
# Evaluate 761/1000
# Evaluate 762/1000
# Evaluate 763/1000
# Evaluate 764/1000
# Evaluate 765/1000
# Evaluate 766/1000
# Evaluate 767/1000
# Evaluate 768/1000
# Evaluate 769/1000
# Evaluate 770/1000
# Evaluate 771/1000
# Evaluate 772/1000
# Evaluate 773/1000
# Evaluate 774/1000
# Evaluate 775/1000
# Evaluate 776/1000
# Evaluate 777/1000
# Evaluate 778/1000
# Evaluate 779/1000
# Evaluate 780/1000
# Evaluate 781/1000
# Evaluate 782/1000
# Evaluate 783/1000
# Evaluate 784/1000
# Evaluate 785/1000
# Evaluate 786/1000
# Evaluate 787/1000
# Evaluate 788/1000
# Evaluate 789/1000
# Evaluate 790/1000
# Evaluate 791/1000
# Evaluate 792/1000
# Evaluate 793/1000
# Evaluate 794/1000
# Evaluate 795/1000
# Evaluate 796/1000
# Evaluate 797/1000
# Evaluate 798/1000
# Evaluate 799/1000
# Evaluate 800/1000
# Evaluate 801/1000
# Evaluate 802/1000
# Evaluate 803/1000
# Evaluate 804/1000
# Evaluate 805/1000
# Evaluate 806/1000
# Evaluate 807/1000
# Evaluate 808/1000
# Evaluate 809/1000
# Evaluate 810/1000
# Evaluate 811/1000
# Evaluate 812/1000
# Evaluate 813/1000
# Evaluate 814/1000
# Evaluate 815/1000
# Evaluate 816/1000
# Evaluate 817/1000
# Evaluate 818/1000
# Evaluate 819/1000
# Evaluate 820/1000
# Evaluate 821/1000
# Evaluate 822/1000
# Evaluate 823/1000
# Evaluate 824/1000
# Evaluate 825/1000
# Evaluate 826/1000
# Evaluate 827/1000
# Evaluate 828/1000
# Evaluate 829/1000
# Evaluate 830/1000
# Evaluate 831/1000
# Evaluate 832/1000
# Evaluate 833/1000
# Evaluate 834/1000
# Evaluate 835/1000
# Evaluate 836/1000
# Evaluate 837/1000
# Evaluate 838/1000
# Evaluate 839/1000
# Evaluate 840/1000
# Evaluate 841/1000
# Evaluate 842/1000
# Evaluate 843/1000
# Evaluate 844/1000
# Evaluate 845/1000
# Evaluate 846/1000
# Evaluate 847/1000
# Evaluate 848/1000
# Evaluate 849/1000
# Evaluate 850/1000
# Evaluate 851/1000
# Evaluate 852/1000
# Evaluate 853/1000
# Evaluate 854/1000
# Evaluate 855/1000
# Evaluate 856/1000
# Evaluate 857/1000
# Evaluate 858/1000
# Evaluate 859/1000
# Evaluate 860/1000
# Evaluate 861/1000
# Evaluate 862/1000
# Evaluate 863/1000
# Evaluate 864/1000
# Evaluate 865/1000
# Evaluate 866/1000
# Evaluate 867/1000
# Evaluate 868/1000
# Evaluate 869/1000
# Evaluate 870/1000
# Evaluate 871/1000
# Evaluate 872/1000
# Evaluate 873/1000
# Evaluate 874/1000
# Evaluate 875/1000
# Evaluate 876/1000
# Evaluate 877/1000
# Evaluate 878/1000
# Evaluate 879/1000
# Evaluate 880/1000
# Evaluate 881/1000
# Evaluate 882/1000
# Evaluate 883/1000
# Evaluate 884/1000
# Evaluate 885/1000
# Evaluate 886/1000
# Evaluate 887/1000
# Evaluate 888/1000
# Evaluate 889/1000
# Evaluate 890/1000
# Evaluate 891/1000
# Evaluate 892/1000
# Evaluate 893/1000
# Evaluate 894/1000
# Evaluate 895/1000
# Evaluate 896/1000
# Evaluate 897/1000
# Evaluate 898/1000
# Evaluate 899/1000
# Evaluate 900/1000
# Evaluate 901/1000
# Evaluate 902/1000
# Evaluate 903/1000
# Evaluate 904/1000
# Evaluate 905/1000
# Evaluate 906/1000
# Evaluate 907/1000
# Evaluate 908/1000
# Evaluate 909/1000
# Evaluate 910/1000
# Evaluate 911/1000
# Evaluate 912/1000
# Evaluate 913/1000
# Evaluate 914/1000
# Evaluate 915/1000
# Evaluate 916/1000
# Evaluate 917/1000
# Evaluate 918/1000
# Evaluate 919/1000
# Evaluate 920/1000
# Evaluate 921/1000
# Evaluate 922/1000
# Evaluate 923/1000
# Evaluate 924/1000
# Evaluate 925/1000
# Evaluate 926/1000
# Evaluate 927/1000
# Evaluate 928/1000
# Evaluate 929/1000
# Evaluate 930/1000
# Evaluate 931/1000
# Evaluate 932/1000
# Evaluate 933/1000
# Evaluate 934/1000
# Evaluate 935/1000
# Evaluate 936/1000
# Evaluate 937/1000
# Evaluate 938/1000
# Evaluate 939/1000
# Evaluate 940/1000
# Evaluate 941/1000
# Evaluate 942/1000
# Evaluate 943/1000
# Evaluate 944/1000
# Evaluate 945/1000
# Evaluate 946/1000
# Evaluate 947/1000
# Evaluate 948/1000
# Evaluate 949/1000
# Evaluate 950/1000
# Evaluate 951/1000
# Evaluate 952/1000
# Evaluate 953/1000
# Evaluate 954/1000
# Evaluate 955/1000
# Evaluate 956/1000
# Evaluate 957/1000
# Evaluate 958/1000
# Evaluate 959/1000
# Evaluate 960/1000
# Evaluate 961/1000
# Evaluate 962/1000
# Evaluate 963/1000
# Evaluate 964/1000
# Evaluate 965/1000
# Evaluate 966/1000
# Evaluate 967/1000
# Evaluate 968/1000
# Evaluate 969/1000
# Evaluate 970/1000
# Evaluate 971/1000
# Evaluate 972/1000
# Evaluate 973/1000
# Evaluate 974/1000
# Evaluate 975/1000
# Evaluate 976/1000
# Evaluate 977/1000
# Evaluate 978/1000
# Evaluate 979/1000
# Evaluate 980/1000
# Evaluate 981/1000
# Evaluate 982/1000
# Evaluate 983/1000
# Evaluate 984/1000
# Evaluate 985/1000
# Evaluate 986/1000
# Evaluate 987/1000
# Evaluate 988/1000
# Evaluate 989/1000
# Evaluate 990/1000
# Evaluate 991/1000
# Evaluate 992/1000
# Evaluate 993/1000
# Evaluate 994/1000
# Evaluate 995/1000
# Evaluate 996/1000
# Evaluate 997/1000
# Evaluate 998/1000
# Evaluate 999/1000
# Evaluate 1000/1000
# VS_Program 0.366

# %%
next_actions = (draw_mcts_newaction,random_action)
#next_actions = (random_action,random_action)
evaluate_algorithm_of('VS_Program {:.3f}',next_actions)
# Out:
# Evaluate 1/1000
# Evaluate 2/1000
# Evaluate 3/1000
# Evaluate 4/1000
# Evaluate 5/1000
# Evaluate 6/1000
# Evaluate 7/1000
# Evaluate 8/1000
# Evaluate 9/1000
# Evaluate 10/1000
# Evaluate 11/1000
# Evaluate 12/1000
# Evaluate 13/1000
# Evaluate 14/1000
# Evaluate 15/1000
# Evaluate 16/1000
# Evaluate 17/1000
# Evaluate 18/1000
# Evaluate 19/1000
# Evaluate 20/1000
# Evaluate 21/1000
# Evaluate 22/1000
# Evaluate 23/1000
# Evaluate 24/1000
# Evaluate 25/1000
# Evaluate 26/1000
# Evaluate 27/1000
# Evaluate 28/1000
# Evaluate 29/1000
# Evaluate 30/1000
# Evaluate 31/1000
# Evaluate 32/1000
# Evaluate 33/1000
# Evaluate 34/1000
# Evaluate 35/1000
# Evaluate 36/1000
# Evaluate 37/1000
# Evaluate 38/1000
# Evaluate 39/1000
# Evaluate 40/1000
# Evaluate 41/1000
# Evaluate 42/1000
# Evaluate 43/1000
# Evaluate 44/1000
# Evaluate 45/1000
# Evaluate 46/1000
# Evaluate 47/1000
# Evaluate 48/1000
# Evaluate 49/1000
# Evaluate 50/1000
# Evaluate 51/1000
# Evaluate 52/1000
# Evaluate 53/1000
# Evaluate 54/1000
# Evaluate 55/1000
# Evaluate 56/1000
# Evaluate 57/1000
# Evaluate 58/1000
# Evaluate 59/1000
# Evaluate 60/1000
# Evaluate 61/1000
# Evaluate 62/1000
# Evaluate 63/1000
# Evaluate 64/1000
# Evaluate 65/1000
# Evaluate 66/1000
# Evaluate 67/1000
# Evaluate 68/1000
# Evaluate 69/1000
# Evaluate 70/1000
# Evaluate 71/1000
# Evaluate 72/1000
# Evaluate 73/1000
# Evaluate 74/1000
# Evaluate 75/1000
# Evaluate 76/1000
# Evaluate 77/1000
# Evaluate 78/1000
# Evaluate 79/1000
# Evaluate 80/1000
# Evaluate 81/1000
# Evaluate 82/1000
# Evaluate 83/1000
# Evaluate 84/1000
# Evaluate 85/1000
# Evaluate 86/1000
# Evaluate 87/1000
# Evaluate 88/1000
# Evaluate 89/1000
# Evaluate 90/1000
# Evaluate 91/1000
# Evaluate 92/1000
# Evaluate 93/1000
# Evaluate 94/1000
# Evaluate 95/1000
# Evaluate 96/1000
# Evaluate 97/1000
# Evaluate 98/1000
# Evaluate 99/1000
# Evaluate 100/1000
# Evaluate 101/1000
# Evaluate 102/1000
# Evaluate 103/1000
# Evaluate 104/1000
# Evaluate 105/1000
# Evaluate 106/1000
# Evaluate 107/1000
# Evaluate 108/1000
# Evaluate 109/1000
# Evaluate 110/1000
# Evaluate 111/1000
# Evaluate 112/1000
# Evaluate 113/1000
# Evaluate 114/1000
# Evaluate 115/1000
# Evaluate 116/1000
# Evaluate 117/1000
# Evaluate 118/1000
# Evaluate 119/1000
# Evaluate 120/1000
# Evaluate 121/1000
# Evaluate 122/1000
# Evaluate 123/1000
# Evaluate 124/1000
# Evaluate 125/1000
# Evaluate 126/1000
# Evaluate 127/1000
# Evaluate 128/1000
# Evaluate 129/1000
# Evaluate 130/1000
# Evaluate 131/1000
# Evaluate 132/1000
# Evaluate 133/1000
# Evaluate 134/1000
# Evaluate 135/1000
# Evaluate 136/1000
# Evaluate 137/1000
# Evaluate 138/1000
# Evaluate 139/1000
# Evaluate 140/1000
# Evaluate 141/1000
# Evaluate 142/1000
# Evaluate 143/1000
# Evaluate 144/1000
# Evaluate 145/1000
# Evaluate 146/1000
# Evaluate 147/1000
# Evaluate 148/1000
# Evaluate 149/1000
# Evaluate 150/1000
# Evaluate 151/1000
# Evaluate 152/1000
# Evaluate 153/1000
# Evaluate 154/1000
# Evaluate 155/1000
# Evaluate 156/1000
# Evaluate 157/1000
# Evaluate 158/1000
# Evaluate 159/1000
# Evaluate 160/1000
# Evaluate 161/1000
# Evaluate 162/1000
# Evaluate 163/1000
# Evaluate 164/1000
# Evaluate 165/1000
# Evaluate 166/1000
# Evaluate 167/1000
# Evaluate 168/1000
# Evaluate 169/1000
# Evaluate 170/1000
# Evaluate 171/1000
# Evaluate 172/1000
# Evaluate 173/1000
# Evaluate 174/1000
# Evaluate 175/1000
# Evaluate 176/1000
# Evaluate 177/1000
# Evaluate 178/1000
# Evaluate 179/1000
# Evaluate 180/1000
# Evaluate 181/1000
# Evaluate 182/1000
# Evaluate 183/1000
# Evaluate 184/1000
# Evaluate 185/1000
# Evaluate 186/1000
# Evaluate 187/1000
# Evaluate 188/1000
# Evaluate 189/1000
# Evaluate 190/1000
# Evaluate 191/1000
# Evaluate 192/1000
# Evaluate 193/1000
# Evaluate 194/1000
# Evaluate 195/1000
# Evaluate 196/1000
# Evaluate 197/1000
# Evaluate 198/1000
# Evaluate 199/1000
# Evaluate 200/1000
# Evaluate 201/1000
# Evaluate 202/1000
# Evaluate 203/1000
# Evaluate 204/1000
# Evaluate 205/1000
# Evaluate 206/1000
# Evaluate 207/1000
# Evaluate 208/1000
# Evaluate 209/1000
# Evaluate 210/1000
# Evaluate 211/1000
# Evaluate 212/1000
# Evaluate 213/1000
# Evaluate 214/1000
# Evaluate 215/1000
# Evaluate 216/1000
# Evaluate 217/1000
# Evaluate 218/1000
# Evaluate 219/1000
# Evaluate 220/1000
# Evaluate 221/1000
# Evaluate 222/1000
# Evaluate 223/1000
# Evaluate 224/1000
# Evaluate 225/1000
# Evaluate 226/1000
# Evaluate 227/1000
# Evaluate 228/1000
# Evaluate 229/1000
# Evaluate 230/1000
# Evaluate 231/1000
# Evaluate 232/1000
# Evaluate 233/1000
# Evaluate 234/1000
# Evaluate 235/1000
# Evaluate 236/1000
# Evaluate 237/1000
# Evaluate 238/1000
# Evaluate 239/1000
# Evaluate 240/1000
# Evaluate 241/1000
# Evaluate 242/1000
# Evaluate 243/1000
# Evaluate 244/1000
# Evaluate 245/1000
# Evaluate 246/1000
# Evaluate 247/1000
# Evaluate 248/1000
# Evaluate 249/1000
# Evaluate 250/1000
# Evaluate 251/1000
# Evaluate 252/1000
# Evaluate 253/1000
# Evaluate 254/1000
# Evaluate 255/1000
# Evaluate 256/1000
# Evaluate 257/1000
# Evaluate 258/1000
# Evaluate 259/1000
# Evaluate 260/1000
# Evaluate 261/1000
# Evaluate 262/1000
# Evaluate 263/1000
# Evaluate 264/1000
# Evaluate 265/1000
# Evaluate 266/1000
# Evaluate 267/1000
# Evaluate 268/1000
# Evaluate 269/1000
# Evaluate 270/1000
# Evaluate 271/1000
# Evaluate 272/1000
# Evaluate 273/1000
# Evaluate 274/1000
# Evaluate 275/1000
# Evaluate 276/1000
# Evaluate 277/1000
# Evaluate 278/1000
# Evaluate 279/1000
# Evaluate 280/1000
# Evaluate 281/1000
# Evaluate 282/1000
# Evaluate 283/1000
# Evaluate 284/1000
# Evaluate 285/1000
# Evaluate 286/1000
# Evaluate 287/1000
# Evaluate 288/1000
# Evaluate 289/1000
# Evaluate 290/1000
# Evaluate 291/1000
# Evaluate 292/1000
# Evaluate 293/1000
# Evaluate 294/1000
# Evaluate 295/1000
# Evaluate 296/1000
# Evaluate 297/1000
# Evaluate 298/1000
# Evaluate 299/1000
# Evaluate 300/1000
# Evaluate 301/1000
# Evaluate 302/1000
# Evaluate 303/1000
# Evaluate 304/1000
# Evaluate 305/1000
# Evaluate 306/1000
# Evaluate 307/1000
# Evaluate 308/1000
# Evaluate 309/1000
# Evaluate 310/1000
# Evaluate 311/1000
# Evaluate 312/1000
# Evaluate 313/1000
# Evaluate 314/1000
# Evaluate 315/1000
# Evaluate 316/1000
# Evaluate 317/1000
# Evaluate 318/1000
# Evaluate 319/1000
# Evaluate 320/1000
# Evaluate 321/1000
# Evaluate 322/1000
# Evaluate 323/1000
# Evaluate 324/1000
# Evaluate 325/1000
# Evaluate 326/1000
# Evaluate 327/1000
# Evaluate 328/1000
# Evaluate 329/1000
# Evaluate 330/1000
# Evaluate 331/1000
# Evaluate 332/1000
# Evaluate 333/1000
# Evaluate 334/1000
# Evaluate 335/1000
# Evaluate 336/1000
# Evaluate 337/1000
# Evaluate 338/1000
# Evaluate 339/1000
# Evaluate 340/1000
# Evaluate 341/1000
# Evaluate 342/1000
# Evaluate 343/1000
# Evaluate 344/1000
# Evaluate 345/1000
# Evaluate 346/1000
# Evaluate 347/1000
# Evaluate 348/1000
# Evaluate 349/1000
# Evaluate 350/1000
# Evaluate 351/1000
# Evaluate 352/1000
# Evaluate 353/1000
# Evaluate 354/1000
# Evaluate 355/1000
# Evaluate 356/1000
# Evaluate 357/1000
# Evaluate 358/1000
# Evaluate 359/1000
# Evaluate 360/1000
# Evaluate 361/1000
# Evaluate 362/1000
# Evaluate 363/1000
# Evaluate 364/1000
# Evaluate 365/1000
# Evaluate 366/1000
# Evaluate 367/1000
# Evaluate 368/1000
# Evaluate 369/1000
# Evaluate 370/1000
# Evaluate 371/1000
# Evaluate 372/1000
# Evaluate 373/1000
# Evaluate 374/1000
# Evaluate 375/1000
# Evaluate 376/1000
# Evaluate 377/1000
# Evaluate 378/1000
# Evaluate 379/1000
# Evaluate 380/1000
# Evaluate 381/1000
# Evaluate 382/1000
# Evaluate 383/1000
# Evaluate 384/1000
# Evaluate 385/1000
# Evaluate 386/1000
# Evaluate 387/1000
# Evaluate 388/1000
# Evaluate 389/1000
# Evaluate 390/1000
# Evaluate 391/1000
# Evaluate 392/1000
# Evaluate 393/1000
# Evaluate 394/1000
# Evaluate 395/1000
# Evaluate 396/1000
# Evaluate 397/1000
# Evaluate 398/1000
# Evaluate 399/1000
# Evaluate 400/1000
# Evaluate 401/1000
# Evaluate 402/1000
# Evaluate 403/1000
# Evaluate 404/1000
# Evaluate 405/1000
# Evaluate 406/1000
# Evaluate 407/1000
# Evaluate 408/1000
# Evaluate 409/1000
# Evaluate 410/1000
# Evaluate 411/1000
# Evaluate 412/1000
# Evaluate 413/1000
# Evaluate 414/1000
# Evaluate 415/1000
# Evaluate 416/1000
# Evaluate 417/1000
# Evaluate 418/1000
# Evaluate 419/1000
# Evaluate 420/1000
# Evaluate 421/1000
# Evaluate 422/1000
# Evaluate 423/1000
# Evaluate 424/1000
# Evaluate 425/1000
# Evaluate 426/1000
# Evaluate 427/1000
# Evaluate 428/1000
# Evaluate 429/1000
# Evaluate 430/1000
# Evaluate 431/1000
# Evaluate 432/1000
# Evaluate 433/1000
# Evaluate 434/1000
# Evaluate 435/1000
# Evaluate 436/1000
# Evaluate 437/1000
# Evaluate 438/1000
# Evaluate 439/1000
# Evaluate 440/1000
# Evaluate 441/1000
# Evaluate 442/1000
# Evaluate 443/1000
# Evaluate 444/1000
# Evaluate 445/1000
# Evaluate 446/1000
# Evaluate 447/1000
# Evaluate 448/1000
# Evaluate 449/1000
# Evaluate 450/1000
# Evaluate 451/1000
# Evaluate 452/1000
# Evaluate 453/1000
# Evaluate 454/1000
# Evaluate 455/1000
# Evaluate 456/1000
# Evaluate 457/1000
# Evaluate 458/1000
# Evaluate 459/1000
# Evaluate 460/1000
# Evaluate 461/1000
# Evaluate 462/1000
# Evaluate 463/1000
# Evaluate 464/1000
# Evaluate 465/1000
# Evaluate 466/1000
# Evaluate 467/1000
# Evaluate 468/1000
# Evaluate 469/1000
# Evaluate 470/1000
# Evaluate 471/1000
# Evaluate 472/1000
# Evaluate 473/1000
# Evaluate 474/1000
# Evaluate 475/1000
# Evaluate 476/1000
# Evaluate 477/1000
# Evaluate 478/1000
# Evaluate 479/1000
# Evaluate 480/1000
# Evaluate 481/1000
# Evaluate 482/1000
# Evaluate 483/1000
# Evaluate 484/1000
# Evaluate 485/1000
# Evaluate 486/1000
# Evaluate 487/1000
# Evaluate 488/1000
# Evaluate 489/1000
# Evaluate 490/1000
# Evaluate 491/1000
# Evaluate 492/1000
# Evaluate 493/1000
# Evaluate 494/1000
# Evaluate 495/1000
# Evaluate 496/1000
# Evaluate 497/1000
# Evaluate 498/1000
# Evaluate 499/1000
# Evaluate 500/1000
# Evaluate 501/1000
# Evaluate 502/1000
# Evaluate 503/1000
# Evaluate 504/1000
# Evaluate 505/1000
# Evaluate 506/1000
# Evaluate 507/1000
# Evaluate 508/1000
# Evaluate 509/1000
# Evaluate 510/1000
# Evaluate 511/1000
# Evaluate 512/1000
# Evaluate 513/1000
# Evaluate 514/1000
# Evaluate 515/1000
# Evaluate 516/1000
# Evaluate 517/1000
# Evaluate 518/1000
# Evaluate 519/1000
# Evaluate 520/1000
# Evaluate 521/1000
# Evaluate 522/1000
# Evaluate 523/1000
# Evaluate 524/1000
# Evaluate 525/1000
# Evaluate 526/1000
# Evaluate 527/1000
# Evaluate 528/1000
# Evaluate 529/1000
# Evaluate 530/1000
# Evaluate 531/1000
# Evaluate 532/1000
# Evaluate 533/1000
# Evaluate 534/1000
# Evaluate 535/1000
# Evaluate 536/1000
# Evaluate 537/1000
# Evaluate 538/1000
# Evaluate 539/1000
# Evaluate 540/1000
# Evaluate 541/1000
# Evaluate 542/1000
# Evaluate 543/1000
# Evaluate 544/1000
# Evaluate 545/1000
# Evaluate 546/1000
# Evaluate 547/1000
# Evaluate 548/1000
# Evaluate 549/1000
# Evaluate 550/1000
# Evaluate 551/1000
# Evaluate 552/1000
# Evaluate 553/1000
# Evaluate 554/1000
# Evaluate 555/1000
# Evaluate 556/1000
# Evaluate 557/1000
# Evaluate 558/1000
# Evaluate 559/1000
# Evaluate 560/1000
# Evaluate 561/1000
# Evaluate 562/1000
# Evaluate 563/1000
# Evaluate 564/1000
# Evaluate 565/1000
# Evaluate 566/1000
# Evaluate 567/1000
# Evaluate 568/1000
# Evaluate 569/1000
# Evaluate 570/1000
# Evaluate 571/1000
# Evaluate 572/1000
# Evaluate 573/1000
# Evaluate 574/1000
# Evaluate 575/1000
# Evaluate 576/1000
# Evaluate 577/1000
# Evaluate 578/1000
# Evaluate 579/1000
# Evaluate 580/1000
# Evaluate 581/1000
# Evaluate 582/1000
# Evaluate 583/1000
# Evaluate 584/1000
# Evaluate 585/1000
# Evaluate 586/1000
# Evaluate 587/1000
# Evaluate 588/1000
# Evaluate 589/1000
# Evaluate 590/1000
# Evaluate 591/1000
# Evaluate 592/1000
# Evaluate 593/1000
# Evaluate 594/1000
# Evaluate 595/1000
# Evaluate 596/1000
# Evaluate 597/1000
# Evaluate 598/1000
# Evaluate 599/1000
# Evaluate 600/1000
# Evaluate 601/1000
# Evaluate 602/1000
# Evaluate 603/1000
# Evaluate 604/1000
# Evaluate 605/1000
# Evaluate 606/1000
# Evaluate 607/1000
# Evaluate 608/1000
# Evaluate 609/1000
# Evaluate 610/1000
# Evaluate 611/1000
# Evaluate 612/1000
# Evaluate 613/1000
# Evaluate 614/1000
# Evaluate 615/1000
# Evaluate 616/1000
# Evaluate 617/1000
# Evaluate 618/1000
# Evaluate 619/1000
# Evaluate 620/1000
# Evaluate 621/1000
# Evaluate 622/1000
# Evaluate 623/1000
# Evaluate 624/1000
# Evaluate 625/1000
# Evaluate 626/1000
# Evaluate 627/1000
# Evaluate 628/1000
# Evaluate 629/1000
# Evaluate 630/1000
# Evaluate 631/1000
# Evaluate 632/1000
# Evaluate 633/1000
# Evaluate 634/1000
# Evaluate 635/1000
# Evaluate 636/1000
# Evaluate 637/1000
# Evaluate 638/1000
# Evaluate 639/1000
# Evaluate 640/1000
# Evaluate 641/1000
# Evaluate 642/1000
# Evaluate 643/1000
# Evaluate 644/1000
# Evaluate 645/1000
# Evaluate 646/1000
# Evaluate 647/1000
# Evaluate 648/1000
# Evaluate 649/1000
# Evaluate 650/1000
# Evaluate 651/1000
# Evaluate 652/1000
# Evaluate 653/1000
# Evaluate 654/1000
# Evaluate 655/1000
# Evaluate 656/1000
# Evaluate 657/1000
# Evaluate 658/1000
# Evaluate 659/1000
# Evaluate 660/1000
# Evaluate 661/1000
# Evaluate 662/1000
# Evaluate 663/1000
# Evaluate 664/1000
# Evaluate 665/1000
# Evaluate 666/1000
# Evaluate 667/1000
# Evaluate 668/1000
# Evaluate 669/1000
# Evaluate 670/1000
# Evaluate 671/1000
# Evaluate 672/1000
# Evaluate 673/1000
# Evaluate 674/1000
# Evaluate 675/1000
# Evaluate 676/1000
# Evaluate 677/1000
# Evaluate 678/1000
# Evaluate 679/1000
# Evaluate 680/1000
# Evaluate 681/1000
# Evaluate 682/1000
# Evaluate 683/1000
# Evaluate 684/1000
# Evaluate 685/1000
# Evaluate 686/1000
# Evaluate 687/1000
# Evaluate 688/1000
# Evaluate 689/1000
# Evaluate 690/1000
# Evaluate 691/1000
# Evaluate 692/1000
# Evaluate 693/1000
# Evaluate 694/1000
# Evaluate 695/1000
# Evaluate 696/1000
# Evaluate 697/1000
# Evaluate 698/1000
# Evaluate 699/1000
# Evaluate 700/1000
# Evaluate 701/1000
# Evaluate 702/1000
# Evaluate 703/1000
# Evaluate 704/1000
# Evaluate 705/1000
# Evaluate 706/1000
# Evaluate 707/1000
# Evaluate 708/1000
# Evaluate 709/1000
# Evaluate 710/1000
# Evaluate 711/1000
# Evaluate 712/1000
# Evaluate 713/1000
# Evaluate 714/1000
# Evaluate 715/1000
# Evaluate 716/1000
# Evaluate 717/1000
# Evaluate 718/1000
# Evaluate 719/1000
# Evaluate 720/1000
# Evaluate 721/1000
# Evaluate 722/1000
# Evaluate 723/1000
# Evaluate 724/1000
# Evaluate 725/1000
# Evaluate 726/1000
# Evaluate 727/1000
# Evaluate 728/1000
# Evaluate 729/1000
# Evaluate 730/1000
# Evaluate 731/1000
# Evaluate 732/1000
# Evaluate 733/1000
# Evaluate 734/1000
# Evaluate 735/1000
# Evaluate 736/1000
# Evaluate 737/1000
# Evaluate 738/1000
# Evaluate 739/1000
# Evaluate 740/1000
# Evaluate 741/1000
# Evaluate 742/1000
# Evaluate 743/1000
# Evaluate 744/1000
# Evaluate 745/1000
# Evaluate 746/1000
# Evaluate 747/1000
# Evaluate 748/1000
# Evaluate 749/1000
# Evaluate 750/1000
# Evaluate 751/1000
# Evaluate 752/1000
# Evaluate 753/1000
# Evaluate 754/1000
# Evaluate 755/1000
# Evaluate 756/1000
# Evaluate 757/1000
# Evaluate 758/1000
# Evaluate 759/1000
# Evaluate 760/1000
# Evaluate 761/1000
# Evaluate 762/1000
# Evaluate 763/1000
# Evaluate 764/1000
# Evaluate 765/1000
# Evaluate 766/1000
# Evaluate 767/1000
# Evaluate 768/1000
# Evaluate 769/1000
# Evaluate 770/1000
# Evaluate 771/1000
# Evaluate 772/1000
# Evaluate 773/1000
# Evaluate 774/1000
# Evaluate 775/1000
# Evaluate 776/1000
# Evaluate 777/1000
# Evaluate 778/1000
# Evaluate 779/1000
# Evaluate 780/1000
# Evaluate 781/1000
# Evaluate 782/1000
# Evaluate 783/1000
# Evaluate 784/1000
# Evaluate 785/1000
# Evaluate 786/1000
# Evaluate 787/1000
# Evaluate 788/1000
# Evaluate 789/1000
# Evaluate 790/1000
# Evaluate 791/1000
# Evaluate 792/1000
# Evaluate 793/1000
# Evaluate 794/1000
# Evaluate 795/1000
# Evaluate 796/1000
# Evaluate 797/1000
# Evaluate 798/1000
# Evaluate 799/1000
# Evaluate 800/1000
# Evaluate 801/1000
# Evaluate 802/1000
# Evaluate 803/1000
# Evaluate 804/1000
# Evaluate 805/1000
# Evaluate 806/1000
# Evaluate 807/1000
# Evaluate 808/1000
# Evaluate 809/1000
# Evaluate 810/1000
# Evaluate 811/1000
# Evaluate 812/1000
# Evaluate 813/1000
# Evaluate 814/1000
# Evaluate 815/1000
# Evaluate 816/1000
# Evaluate 817/1000
# Evaluate 818/1000
# Evaluate 819/1000
# Evaluate 820/1000
# Evaluate 821/1000
# Evaluate 822/1000
# Evaluate 823/1000
# Evaluate 824/1000
# Evaluate 825/1000
# Evaluate 826/1000
# Evaluate 827/1000
# Evaluate 828/1000
# Evaluate 829/1000
# Evaluate 830/1000
# Evaluate 831/1000
# Evaluate 832/1000
# Evaluate 833/1000
# Evaluate 834/1000
# Evaluate 835/1000
# Evaluate 836/1000
# Evaluate 837/1000
# Evaluate 838/1000
# Evaluate 839/1000
# Evaluate 840/1000
# Evaluate 841/1000
# Evaluate 842/1000
# Evaluate 843/1000
# Evaluate 844/1000
# Evaluate 845/1000
# Evaluate 846/1000
# Evaluate 847/1000
# Evaluate 848/1000
# Evaluate 849/1000
# Evaluate 850/1000
# Evaluate 851/1000
# Evaluate 852/1000
# Evaluate 853/1000
# Evaluate 854/1000
# Evaluate 855/1000
# Evaluate 856/1000
# Evaluate 857/1000
# Evaluate 858/1000
# Evaluate 859/1000
# Evaluate 860/1000
# Evaluate 861/1000
# Evaluate 862/1000
# Evaluate 863/1000
# Evaluate 864/1000
# Evaluate 865/1000
# Evaluate 866/1000
# Evaluate 867/1000
# Evaluate 868/1000
# Evaluate 869/1000
# Evaluate 870/1000
# Evaluate 871/1000
# Evaluate 872/1000
# Evaluate 873/1000
# Evaluate 874/1000
# Evaluate 875/1000
# Evaluate 876/1000
# Evaluate 877/1000
# Evaluate 878/1000
# Evaluate 879/1000
# Evaluate 880/1000
# Evaluate 881/1000
# Evaluate 882/1000
# Evaluate 883/1000
# Evaluate 884/1000
# Evaluate 885/1000
# Evaluate 886/1000
# Evaluate 887/1000
# Evaluate 888/1000
# Evaluate 889/1000
# Evaluate 890/1000
# Evaluate 891/1000
# Evaluate 892/1000
# Evaluate 893/1000
# Evaluate 894/1000
# Evaluate 895/1000
# Evaluate 896/1000
# Evaluate 897/1000
# Evaluate 898/1000
# Evaluate 899/1000
# Evaluate 900/1000
# Evaluate 901/1000
# Evaluate 902/1000
# Evaluate 903/1000
# Evaluate 904/1000
# Evaluate 905/1000
# Evaluate 906/1000
# Evaluate 907/1000
# Evaluate 908/1000
# Evaluate 909/1000
# Evaluate 910/1000
# Evaluate 911/1000
# Evaluate 912/1000
# Evaluate 913/1000
# Evaluate 914/1000
# Evaluate 915/1000
# Evaluate 916/1000
# Evaluate 917/1000
# Evaluate 918/1000
# Evaluate 919/1000
# Evaluate 920/1000
# Evaluate 921/1000
# Evaluate 922/1000
# Evaluate 923/1000
# Evaluate 924/1000
# Evaluate 925/1000
# Evaluate 926/1000
# Evaluate 927/1000
# Evaluate 928/1000
# Evaluate 929/1000
# Evaluate 930/1000
# Evaluate 931/1000
# Evaluate 932/1000
# Evaluate 933/1000
# Evaluate 934/1000
# Evaluate 935/1000
# Evaluate 936/1000
# Evaluate 937/1000
# Evaluate 938/1000
# Evaluate 939/1000
# Evaluate 940/1000
# Evaluate 941/1000
# Evaluate 942/1000
# Evaluate 943/1000
# Evaluate 944/1000
# Evaluate 945/1000
# Evaluate 946/1000
# Evaluate 947/1000
# Evaluate 948/1000
# Evaluate 949/1000
# Evaluate 950/1000
# Evaluate 951/1000
# Evaluate 952/1000
# Evaluate 953/1000
# Evaluate 954/1000
# Evaluate 955/1000
# Evaluate 956/1000
# Evaluate 957/1000
# Evaluate 958/1000
# Evaluate 959/1000
# Evaluate 960/1000
# Evaluate 961/1000
# Evaluate 962/1000
# Evaluate 963/1000
# Evaluate 964/1000
# Evaluate 965/1000
# Evaluate 966/1000
# Evaluate 967/1000
# Evaluate 968/1000
# Evaluate 969/1000
# Evaluate 970/1000
# Evaluate 971/1000
# Evaluate 972/1000
# Evaluate 973/1000
# Evaluate 974/1000
# Evaluate 975/1000
# Evaluate 976/1000
# Evaluate 977/1000
# Evaluate 978/1000
# Evaluate 979/1000
# Evaluate 980/1000
# Evaluate 981/1000
# Evaluate 982/1000
# Evaluate 983/1000
# Evaluate 984/1000
# Evaluate 985/1000
# Evaluate 986/1000
# Evaluate 987/1000
# Evaluate 988/1000
# Evaluate 989/1000
# Evaluate 990/1000
# Evaluate 991/1000
# Evaluate 992/1000
# Evaluate 993/1000
# Evaluate 994/1000
# Evaluate 995/1000
# Evaluate 996/1000
# Evaluate 997/1000
# Evaluate 998/1000
# Evaluate 999/1000
# Evaluate 1000/1000
# VS_Program 0.382

# %%
h
